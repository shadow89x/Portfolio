# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')
# %matplotlib inline

# %%
pd.set_option('display.max_columns',None)

# %%
population = pd.read_csv('country_population.csv')
fertility = pd.read_csv('fertility_rate.csv')
life = pd.read_csv('life_expectancy.csv')

# %%
population.head()
# Out:
#   Country Name Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996351.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5643182.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965        1966  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0     57715.0
# 1  9166764.0  9345868.0  9533954.0  9731361.0  9938414.0  10152331.0
# 2  5753024.0  5866061.0  5980417.0  6093321.0  6203299.0   6309770.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0   1914573.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0     19647.0
#
#          1967        1968        1969        1970        1971        1972  \
# ...

# %%
fertility.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965   1966   1967  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  3.625  3.417
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619  7.618  7.613
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773  5.581  5.394
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1968   1969   1970   1971   1972   1973   1974   1975   1976   1977  \
# ...

# %%
life.head()
# Out:
#   Country Name Country Code                           Indicator Name  \
# 0        Aruba          ABW  Life expectancy at birth, total (years)
# 1  Afghanistan          AFG  Life expectancy at birth, total (years)
# 2       Angola          AGO  Life expectancy at birth, total (years)
# 3      Albania          ALB  Life expectancy at birth, total (years)
# 4      Andorra          AND  Life expectancy at birth, total (years)
#
#    Indicator Code    1960    1961    1962    1963    1964    1965    1966  \
# 0  SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435  67.762
# 1  SP.DYN.LE00.IN  32.292  32.742  33.185  33.624  34.060  34.495  34.928
# 2  SP.DYN.LE00.IN  33.251  33.573  33.914  34.272  34.645  35.031  35.426
# 3  SP.DYN.LE00.IN  62.279  63.298  64.187  64.911  65.461  65.848  66.108
# 4  SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#      1967    1968    1969    1970    1971    1972    1973    1974    1975  \
# ...

# %%
#Top 12 GDP countries' population.
india = population.loc[population['Country Name'] == 'India']
china = population.loc[population['Country Name'] == 'China']
japan = population.loc[population['Country Name'] == 'Japan']
US = population.loc[population['Country Name'] == 'United States']
UK = population.loc[population['Country Name'] == 'United Kingdom']
Germany = population.loc[population['Country Name'] == 'Germany']
France = population.loc[population['Country Name'] == 'France']
Italy = population.loc[population['Country Name'] == 'Italy']
Brazil = population.loc[population['Country Name'] == 'Brazil']
Canada = population.loc[population['Country Name'] == 'Canada']
Korea = population.loc[population['Country Name'] == 'Korea, Rep.']
Russia = population.loc[population['Country Name'] == 'Russian Federation']


x = range(1959, 2016)
size = india.size
yindia = india.iloc[0, 4:size]
ychina = china.iloc[0, 4:size]
yjapan = japan.iloc[0, 4:size]
yUS = US.iloc[0, 4:size]
yUK = UK.iloc[0, 4:size]
yGermany = Germany.iloc[0, 4:size]
yFrance = France.iloc[0, 4:size]
yItaly = Italy.iloc[0, 4:size]
yBrazil = Brazil.iloc[0, 4:size]
yCanada = Canada.iloc[0, 4:size]
yKorea = Korea.iloc[0, 4:size]
yRussia = Russia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, yindia)
plt.plot(x, ychina)
plt.plot(x, yjapan)
plt.plot(x, yUS)
plt.plot(x, yUK)
plt.plot(x, yGermany)
plt.plot(x, yFrance)
plt.plot(x, yItaly)
plt.plot(x, yBrazil)
plt.plot(x, yKorea)
plt.plot(x, yCanada)
plt.plot(x, yRussia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('population / billions')
plt.legend(['India','China','Japan','United States','United Kingdom','Germany','France','Italy','Brazil','South Korea','Canada','Russia'])

# %%
#Bottom 12 GDP countries' population.
Taci = population.loc[population['Country Name'] == 'Turks and Caicos Islands']
Syria = population.loc[population['Country Name'] == 'Syrian Arab Republic']
Sudan = population.loc[population['Country Name'] == 'Sudan']
Tuvalu = population.loc[population['Country Name'] == 'Tuvalu']
SintMaarten = population.loc[population['Country Name'] == 'Sint Maarten (Dutch part)']
Pakistan = population.loc[population['Country Name'] == 'Pakistan']
NewCaledonia = population.loc[population['Country Name'] == 'New Caledonia']
Nauru = population.loc[population['Country Name'] == 'Nauru']
Monaco = population.loc[population['Country Name'] == 'Monaco']
Liechtenstein = population.loc[population['Country Name'] == 'Liechtenstein']
Greenland = population.loc[population['Country Name'] == 'Greenland']
FrenchPolynesia = population.loc[population['Country Name'] == 'French Polynesia']

x = range(1959, 2016)
size = Taci.size
yTaci = Taci.iloc[0, 4:size]
ySyria = Syria.iloc[0, 4:size]
ySudan = Sudan.iloc[0, 4:size]
yTuvalu = Tuvalu.iloc[0, 4:size]
ySintMaarten = SintMaarten.iloc[0, 4:size]
yPakistan = Pakistan.iloc[0, 4:size]
yNewCaledonia = NewCaledonia.iloc[0, 4:size]
yNauru = Nauru.iloc[0, 4:size]
yMonaco = Monaco.iloc[0, 4:size]
yLiechtenstein = Liechtenstein.iloc[0, 4:size]
yGreenland = Greenland.iloc[0, 4:size]
yFrenchPolynesia = FrenchPolynesia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, yTaci)
plt.plot(x, ySyria)
plt.plot(x, ySudan)
plt.plot(x, yTuvalu)
plt.plot(x, ySintMaarten)
plt.plot(x, yPakistan)
plt.plot(x, yNewCaledonia)
plt.plot(x, yNauru)
plt.plot(x, yMonaco)
plt.plot(x, yLiechtenstein)
plt.plot(x, yGreenland)
plt.plot(x, yFrenchPolynesia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('population / billions')
plt.legend(['Taci','Syria','Sudan','Tuvalu','Sint Maarten','Pakistan','New Caledonia','Nauru','Monaco','Liechtenstein','Greenland','French Polynesia'])

# %%
#pre processing for world data.

temp_pop= population
temp_pop.drop(columns=['Country Name','Country Code', 'Indicator Name', 'Indicator Code'],axis =1, inplace=True)
pop_sum=temp_pop.sum()
pop_sum=pd.DataFrame(pop_sum).reset_index()
pop_sum.columns= ['Year','Total Population']

# %%
# World population
plt.figure(figsize=(15,8))
plt.plot(pop_sum['Year'], pop_sum['Total Population'])
plt.title('Global Population from 1960 to 2016')
plt.ylabel('Population / Billions')
plt.xticks(rotation =90)
plt.show()

# %%
#Top 12 GDP countries' fertility rate.
findia = fertility.loc[fertility['Country Name'] == 'India']
fchina = fertility.loc[fertility['Country Name'] == 'China']
fjapan = fertility.loc[fertility['Country Name'] == 'Japan']
fUS = fertility.loc[fertility['Country Name'] == 'United States']
fUK = fertility.loc[fertility['Country Name'] == 'United Kingdom']
fGermany = fertility.loc[fertility['Country Name'] == 'Germany']
fFrance = fertility.loc[fertility['Country Name'] == 'France']
fItaly = fertility.loc[fertility['Country Name'] == 'Italy']
fBrazil = fertility.loc[fertility['Country Name'] == 'Brazil']
fCanada = fertility.loc[fertility['Country Name'] == 'Canada']
fKorea = fertility.loc[fertility['Country Name'] == 'Korea, Rep.']
fRussia = fertility.loc[fertility['Country Name'] == 'Russian Federation']

x = range(1959, 2016)
size = findia.size
fyindia = findia.iloc[0, 4:size]
fychina = fchina.iloc[0, 4:size]
fyjapan = fjapan.iloc[0, 4:size]
fyUS = fUS.iloc[0, 4:size]
fyUK = fUK.iloc[0, 4:size]
fyGermany = fGermany.iloc[0, 4:size]
fyFrance = fFrance.iloc[0, 4:size]
fyItaly = fItaly.iloc[0, 4:size]
fyBrazil = fBrazil.iloc[0, 4:size]
fyCanada = fCanada.iloc[0, 4:size]
fyKorea = fKorea.iloc[0, 4:size]
fyRussia = fRussia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, fyindia)
plt.plot(x, fychina)
plt.plot(x, fyjapan)
plt.plot(x, fyUS)
plt.plot(x, fyUK)
plt.plot(x, fyGermany)
plt.plot(x, fyFrance)
plt.plot(x, fyItaly)
plt.plot(x, fyBrazil)
plt.plot(x, fyKorea)
plt.plot(x, fyCanada)
plt.plot(x, fyRussia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('Child per Women')
plt.legend(['India','China','Japan','United States','United Kingdom','Germany','France','Italy','Brazil','South Korea','Canada','Russia'])

# %%
#Bottom 12 GDP countries' fertility rate.
fTaci = fertility.loc[fertility['Country Name'] == 'Turks and Caicos Islands']
fSyria = fertility.loc[fertility['Country Name'] == 'Syrian Arab Republic']
fSudan = fertility.loc[fertility['Country Name'] == 'Sudan']
fTuvalu = fertility.loc[fertility['Country Name'] == 'Tuvalu']
fSintMaarten = fertility.loc[fertility['Country Name'] == 'Sint Maarten (Dutch part)']
fPakistan = fertility.loc[fertility['Country Name'] == 'Pakistan']
fNewCaledonia = fertility.loc[fertility['Country Name'] == 'New Caledonia']
fNauru = fertility.loc[fertility['Country Name'] == 'Nauru']
fMonaco = fertility.loc[fertility['Country Name'] == 'Monaco']
fLiechtenstein = fertility.loc[fertility['Country Name'] == 'Liechtenstein']
fGreenland = fertility.loc[fertility['Country Name'] == 'Greenland']
fFrenchPolynesia = fertility.loc[fertility['Country Name'] == 'French Polynesia']

x = range(1959, 2016)
size = fTaci.size
fyTaci = fTaci.iloc[0, 4:size]
fySyria = fSyria.iloc[0, 4:size]
fySudan = fSudan.iloc[0, 4:size]
fyTuvalu = fTuvalu.iloc[0, 4:size]
fySintMaarten = fSintMaarten.iloc[0, 4:size]
fyPakistan = fPakistan.iloc[0, 4:size]
fyNewCaledonia = fNewCaledonia.iloc[0, 4:size]
fyNauru = fNauru.iloc[0, 4:size]
fyMonaco = fMonaco.iloc[0, 4:size]
fyLiechtenstein = fLiechtenstein.iloc[0, 4:size]
fyGreenland = fGreenland.iloc[0, 4:size]
fyFrenchPolynesia = fFrenchPolynesia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, fyTaci)
plt.plot(x, fySyria)
plt.plot(x, fySudan)
plt.plot(x, fyTuvalu)
plt.plot(x, fySintMaarten)
plt.plot(x, fyPakistan)
plt.plot(x, fyNewCaledonia)
plt.plot(x, fyNauru)
plt.plot(x, fyMonaco)
plt.plot(x, fyLiechtenstein)
plt.plot(x, fyGreenland)
plt.plot(x, fyFrenchPolynesia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('Child per Women')
plt.legend(['Taci','Syria','Sudan','Tuvalu','Sint Maarten','Pakistan','New Caledonia','Nauru','Monaco','Liechtenstein','Greenland','French Polynesia'])

# %%
temp_fert= fertility
temp_fert.drop(columns=['Country Name','Country Code', 'Indicator Name', 'Indicator Code'],axis =1,inplace=True)
fert_mean=temp_fert.mean()
fert_mean=pd.DataFrame(fert_mean).reset_index()
fert_mean.columns= ['Year','Total Population']

# %%
#World fertility rate.
plt.figure(figsize=(15,8))
plt.plot(fert_mean['Year'], fert_mean['Total Population'])
plt.title('Global child per women')
plt.xticks(rotation =90)
plt.show()

# %%
#preprocessing for top12 and bottom12 fertility average.
botfert=fertility.iloc[[226,225,204,243,223,182, 170, 177, 147, 135, 89, 197]]
botfm = botfert.mean()

topfert=fertility.iloc[[107,38,117,249,79,53,75,114,27,33,124,200]]
topfm = topfert.mean()

# %%
#graphing Top12,Bottom12,and World fertility rate.
plt.figure(figsize=(15,8))
topfm.plot()
botfm.plot()
plt.plot(fert_mean['Year'], fert_mean['Total Population'])

plt.title('Fertility rate')
plt.xticks(rotation =90)
plt.legend(['top12','bottom12','world'])
plt.show()

# %%
#Top 12 GDP countries' life expectancy.
lfindia = life.loc[life['Country Name'] == 'India']
lfchina = life.loc[life['Country Name'] == 'China']
lfjapan = life.loc[life['Country Name'] == 'Japan']
lfUS = life.loc[life['Country Name'] == 'United States']
lfUK = life.loc[life['Country Name'] == 'United Kingdom']
lfGermany = life.loc[life['Country Name'] == 'Germany']
lfFrance = life.loc[life['Country Name'] == 'France']
lfItaly = life.loc[life['Country Name'] == 'Italy']
lfBrazil = life.loc[life['Country Name'] == 'Brazil']
lfCanada = life.loc[life['Country Name'] == 'Canada']
lfKorea = life.loc[life['Country Name'] == 'Korea, Rep.']
lfRussia = life.loc[life['Country Name'] == 'Russian Federation']

x = range(1959, 2016)
size = lfindia.size
lfyindia = lfindia.iloc[0, 4:size]
lfychina = lfchina.iloc[0, 4:size]
lfyjapan = lfjapan.iloc[0, 4:size]
lfyUS = lfUS.iloc[0, 4:size]
lfyUK = lfUK.iloc[0, 4:size]
lfyGermany = lfGermany.iloc[0, 4:size]
lfyFrance = lfFrance.iloc[0, 4:size]
lfyItaly = lfItaly.iloc[0, 4:size]
lfyBrazil = lfBrazil.iloc[0, 4:size]
lfyCanada = lfCanada.iloc[0, 4:size]
lfyKorea = lfKorea.iloc[0, 4:size]
lfyRussia = lfRussia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, lfyindia)
plt.plot(x, lfychina)
plt.plot(x, lfyjapan)
plt.plot(x, lfyUS)
plt.plot(x, lfyUK)
plt.plot(x, lfyGermany)
plt.plot(x, lfyFrance)
plt.plot(x, lfyItaly)
plt.plot(x, lfyBrazil)
plt.plot(x, lfyKorea)
plt.plot(x, lfyCanada)
plt.plot(x, lfyRussia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('Life Expectancy')
plt.legend(['India','China','Japan','United States','United Kingdom','Germany','France','Italy','Brazil','South Korea','Canada','Russia'])

# %%
#Bottom 12 GDP countries' life expectancy.
lfTaci = life.loc[life['Country Name'] == 'Turks and Caicos Islands']
lfSyria = life.loc[life['Country Name'] == 'Syrian Arab Republic']
lfSudan = life.loc[life['Country Name'] == 'Sudan']
lfTuvalu = life.loc[life['Country Name'] == 'Tuvalu']
lfSintMaarten = life.loc[life['Country Name'] == 'Sint Maarten (Dutch part)']
lfPakistan = life.loc[life['Country Name'] == 'Pakistan']
lfNewCaledonia = life.loc[life['Country Name'] == 'New Caledonia']
lfNauru = life.loc[life['Country Name'] == 'Nauru']
lfMonaco = life.loc[life['Country Name'] == 'Monaco']
lfLiechtenstein = life.loc[life['Country Name'] == 'Liechtenstein']
lfGreenland = life.loc[life['Country Name'] == 'Greenland']
lfFrenchPolynesia = life.loc[life['Country Name'] == 'French Polynesia']

x = range(1959, 2016)
size = lfTaci.size
lfyTaci = lfTaci.iloc[0, 4:size]
lfySyria = lfSyria.iloc[0, 4:size]
lfySudan = lfSudan.iloc[0, 4:size]
lfyTuvalu = lfTuvalu.iloc[0, 4:size]
lfySintMaarten = lfSintMaarten.iloc[0, 4:size]
lfyPakistan = lfPakistan.iloc[0, 4:size]
lfyNewCaledonia = lfNewCaledonia.iloc[0, 4:size]
lfyNauru = lfNauru.iloc[0, 4:size]
lfyMonaco = lfMonaco.iloc[0, 4:size]
lfyLiechtenstein = lfLiechtenstein.iloc[0, 4:size]
lfyGreenland = lfGreenland.iloc[0, 4:size]
lfyFrenchPolynesia = lfFrenchPolynesia.iloc[0, 4:size]

plt.figure(figsize=(15,10))
plt.plot(x, lfyTaci)
plt.plot(x, lfySyria)
plt.plot(x, lfySudan)
plt.plot(x, lfyTuvalu)
plt.plot(x, lfySintMaarten)
plt.plot(x, lfyPakistan)
plt.plot(x, lfyNewCaledonia)
plt.plot(x, lfyNauru)
plt.plot(x, lfyMonaco)
plt.plot(x, lfyLiechtenstein)
plt.plot(x, lfyGreenland)
plt.plot(x, lfyFrenchPolynesia)
plt.xlabel('Year (1960 - 2016)')
plt.ylabel('Life Expectancy')
plt.legend(['Taci','Syria','Sudan','Tuvalu','Sint Maarten','Pakistan','New Caledonia','Nauru','Monaco','Liechtenstein','Greenland','French Polynesia'])

# %%
temp_lf= life
temp_lf.drop(columns=['Country Name','Country Code', 'Indicator Name', 'Indicator Code'],axis =1,inplace=True)
lf_mean=temp_lf.mean()
lf_mean=pd.DataFrame(lf_mean).reset_index()
lf_mean.columns= ['Year','Total Population']

# %%
#World life expectancy.
plt.figure(figsize=(15,8))
plt.plot(lf_mean['Year'], lf_mean['Total Population'])
plt.title('Global life expectancy')
plt.xticks(rotation =90)
plt.show()

# %%
#preprocessing for top12 and bottom12 fertility average.
botlf=life.iloc[[226,225,204,243,223,182, 170, 177, 147, 135, 89, 197]]
botlm = botlf.mean()

toplf=life.iloc[[107,38,117,249,79,53,75,114,27,33,124,200]]
toplm = toplf.mean()

# %%
#graphing Top12,Bottom12,and World life expectancy.
plt.figure(figsize=(15,8))
toplm.plot()
botlm.plot()
plt.plot(lf_mean['Year'], lf_mean['Total Population'])

plt.title('Life expectancy')
plt.xticks(rotation =90)
plt.legend(['top12','bottom12','world'])
plt.show()

# %% [markdown]
# # here comes my hypothesis that there will be a pattern which satisfy below.
#  1) If fertility rate is 2. then there should not incresing population
#  2) If there still incresing population when fertility rate is 2, then it must be incresing life expectancy related
#  3) Thus,if total population multiplied by fertility rate - 1 (because population supposed to be constant when fertility is 2)
#     and devided by life expectancy,then result supposed to be a constant line.

# %%
# graphing based on my hypothesis.
po = []
for i in range(56):
    po.append((pop_sum['Total Population'][i] * (fert_mean['Total Population'][i]-1) )/ lf_mean['Total Population'])
plt.plot(x[1:], po)
plt.legend(["Population multiplied by fertility"])
plt.show()

# %% [markdown]
# It shape almost a constant line but there still are some curves in the middle. I believe it is because life expectancy is not
# equal to the death rate in a particular year.
